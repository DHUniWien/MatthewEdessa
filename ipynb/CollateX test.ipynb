# %%
from collatex import *
import json

# %%
wits = None
with open("test.json", encoding='utf-8') as fh:
    wits = json.load(fh)

collate(wits, output='html', segmentation=False, near_match=True)
# Out:
# <table>
#     <tr>
#         <td>M1731.json</td>
#         <td>Իսկ</td>
#         <td>-</td>
#         <td>ընդ</td>
#         <td>աւուրսն</td>
#         <td>ընդ</td>
#         <td>այնոսիկ,</td>
#         <td>և</td>
#         <td>ի</td>
#         <td>ամին</td>
#         <td>ն՟ա՟.</td>
#         <td>-</td>
#         <td>-</td>
#         <td>եղև</td>
#         <td>սով</td>
#         <td>սաստիկ</td>
#         <td>ի</td>
#         <td>բզմ</td>
#         <td>տեղիս.</td>
#         <td>-</td>
#         <td>բայց</td>
#         <td>յաշխարհն</td>
#         <td>հարաւոյ</td>
#         <td>ի</td>
#         <td>յերկրին</td>
#         <td>տաճկա՛ց</td>
#         <td>եղև</td>
#         <td>նեղութի</td>
#         <td>մեծ</td>
#         <td>և</td>
#         <td>առաւել</td>
#         <td>քան</td>
#         <td>զամ</td>
#         <td>ի</td>
#         <td>միջա֊գետս.</td>
#         <td>և</td>
#         <td>ի</td>
#         <td>խստութե</td>
#         <td>սովոյն</td>
#         <td>տագնապ</td>
# ...
